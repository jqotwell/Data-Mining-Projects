# %% [markdown]
# # Classifying Mushrooms as Venomous or Non-Venomous Using Decision Tree Classfier

# %%
from sklearn.tree import DecisionTreeClassifier as dt
from sklearn import tree
import pandas as pd
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import numpy as np
from matplotlib import pyplot as plt

# %%
mushrooms=pd.read_csv("mushrooms.csv")

# %%
x=mushrooms.iloc[:,1:23]
x=pd.get_dummies(x)
y=mushrooms.iloc[:,0]
model6=dt()
fold=KFold(10)
score6=cross_val_score(model6,x,y,cv=fold)
print(np.mean(score6))
# Out:
# 1.0

# %%
mushrooms=mushrooms.sample(frac=1)

x=mushrooms.iloc[:,1:23]
x=pd.get_dummies(x)
xtrain=x.iloc[0:5000,:]
xtest=x.iloc[5000:,:]
ytrain=mushrooms.iloc[0:5000,0]
ytest=mushrooms.iloc[5000:,0]

# %%
model5=dt()
model5.fit(xtrain,ytrain)
print(model5.score(xtest,ytest))
# Out:
# 1.0

# %%
mushrooms=mushrooms.sample(frac=1)

x=mushrooms.iloc[:,1:23]
x=pd.get_dummies(x)
x=x.iloc[0:500,:]
y=mushrooms.iloc[0:500,0]
x.head()
# Out:
#       cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 7682            0            0            0            0            0
# 2604            0            0            1            0            0
# 6968            0            0            1            0            0
# 2238            0            0            0            0            0
# 6661            0            0            0            0            0
#
#       cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# 7682            1              0              0              1              0
# 2604            0              1              0              0              0
# 6968            0              0              0              1              0
# 2238            1              1              0              0              0
# 6661            1              0              0              1              0
#
# ...

# %%
model2=dt()
fold=KFold(10)
score2=cross_val_score(model2,x,y,cv=fold)
print(np.mean(score2))
# Out:
# 0.9940000000000001

# %%
mushrooms=mushrooms.sample(frac=1)

x=mushrooms.iloc[:,1:23]
x=pd.get_dummies(x)
x=x.iloc[0:5000,:]
y=mushrooms.iloc[0:5000,0]
x.head()
# Out:
#       cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 3909            0            0            1            0            0
# 8020            0            0            0            1            0
# 3097            0            0            0            0            0
# 7906            0            0            0            0            0
# 7479            1            0            0            0            0
#
#       cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# 3909            0              1              0              0              0
# 8020            0              0              0              0              1
# 3097            1              0              0              1              0
# 7906            1              0              0              0              1
# 7479            0              1              0              0              0
#
# ...

# %%
model2=dt()
fold=KFold(10)
score2=cross_val_score(model2,x,y,cv=fold)
print(np.mean(score2))
# Out:
# 0.9996

# %%
model3=dt(max_leaf_nodes=10)
score3=cross_val_score(model3,x,y,cv=fold)
print(np.mean(score3))
# Out:
# 0.9984

# %%
model4=dt(max_leaf_nodes=30)
score4=cross_val_score(model4,x,y,cv=fold)
print(np.mean(score4))
# Out:
# 1.0

# %%
model3.fit(x,y)
tree.plot_tree(model3,feature_names=list(x))
plt.rcParams["figure.figsize"] = (20,15)
plt.show()

# %%
print(x.iloc[:,53])
# Out:
# 3909    0
# 8020    0
# 3097    0
# 7906    0
# 7479    0
#        ..
# 7300    0
# 875     0
# 1005    0
# 4408    0
# 3904    0
# Name: stalk-root_c, Length: 5000, dtype: uint8

# %%
tree.export_text(model3)
# Out:
# '|--- feature_27 <= 0.50\n|   |--- feature_53 <= 0.50\n|   |   |--- feature_63 <= 0.50\n|   |   |   |--- feature_25 <= 0.50\n|   |   |   |   |--- feature_22 <= 0.50\n|   |   |   |   |   |--- class: p\n|   |   |   |   |--- feature_22 >  0.50\n|   |   |   |   |   |--- class: e\n|   |   |   |--- feature_25 >  0.50\n|   |   |   |   |--- class: e\n|   |   |--- feature_63 >  0.50\n|   |   |   |--- class: e\n|   |--- feature_53 >  0.50\n|   |   |--- feature_94 <= 0.50\n|   |   |   |--- class: p\n|   |   |--- feature_94 >  0.50\n|   |   |   |--- class: e\n|--- feature_27 >  0.50\n|   |--- feature_100 <= 0.50\n|   |   |--- feature_63 <= 0.50\n|   |   |   |--- class: e\n|   |   |--- feature_63 >  0.50\n|   |   |   |--- feature_94 <= 0.50\n|   |   |   |   |--- class: p\n|   |   |   |--- feature_94 >  0.50\n|   |   |   |   |--- class: e\n|   |--- feature_100 >  0.50\n|   |   |--- class: p\n'
